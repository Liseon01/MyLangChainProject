# %%
import os
from typing import List, Dict, Any

try:
    from langchain_text_splitters import RecursiveCharacterTextSplitter
except Exception:
    from langchain.text_splitter import RecursiveCharacterTextSplitter

from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import FAISS
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from langchain_upstage import UpstageEmbeddings, ChatUpstage

def classify_dispute_type(query: str) -> str:
    """Heuristic dispute type classifier based on keywords."""
    game_keywords = ["게임", "아이템", "계정", "캐릭터", "레벨", "길드", "온라인게임"]
    elearning_keywords = ["강의", "온라인교육", "이러닝", "수강", "환불", "화상교육"]
    web_keywords = ["웹사이트", "무료체험", "자동결제", "구독", "사이트"]

    q = query.lower()
    if any(k in q for k in game_keywords):
        return "게임"
    if any(k in q for k in elearning_keywords):
        return "이러닝"
    if any(k in q for k in web_keywords):
        return "웹콘텐츠"
    return "기타"


def build_rag_chain(
    pdf_path: str = "../data/콘텐츠분쟁해결_사례.pdf",
    use_mmr: bool = False,
    k: int = 5,
    temperature: float = 0.0,
) -> Dict[str, Any]:
    """
    Build a complete RAG pipeline:
    - Load PDF
    - Split into chunks with law-friendly separators
    - Embed with Upstage (solar-embedding-1-large)
    - Vector store with FAISS
    - Retriever (similarity or MMR)
    - LLM (solar-pro) with strict prompt for legal advisory
    - RetrievalQA chain returning source documents
    """

    loader = PyPDFLoader(pdf_path)
    documents = loader.load()

    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1500,          
        chunk_overlap=300,        
        separators=[
            "\n【사건개요】",
            "\n【쟁점사항】",
            "\n【처리경위】",
            "\n【처리결과】",
            "\n■", "\n\n", "\n", ".", " ", ""
        ],
    )
    splits = text_splitter.split_documents(documents)

    embeddings = UpstageEmbeddings(model="solar-embedding-1-large")

    vectorstore = FAISS.from_documents(splits, embeddings)

    retriever = vectorstore.as_retriever(
        search_type="mmr" if use_mmr else "similarity",
        search_kwargs={"k": k} if not use_mmr else {"k": k, "fetch_k": max(k * 4, 16)},
    )

    llm = ChatUpstage(
        model="solar-pro",
        base_url="https://api.upstage.ai/v1",
        temperature=temperature,
    )

    strict_prompt_template = """당신은 콘텐츠 분야 전문 법률 자문사입니다.

다음 정보를 절대적으로 준수하세요:
- 제공된 분쟁사례(context) 안에서만 답변하세요.
- context에 근거가 없거나 불확실하면 답변하지 말고 반드시 "제시된 사례집에서는 확인할 수 없습니다"라고만 말하세요.
- 추정/일반지식/외부자료 인용을 금지합니다.

관련 분쟁사례:
{context}

상담 내용:
{question}

답변 가이드라인:
1. 사례를 근거로 답변하세요.
2. 관련 법령을 명시하세요.
3. 단계별 해결방안을 제시하세요.
4. 유사 사례를 참조하세요.
5. 없는 정보는 "제시된 사례집에서는 확인할 수 없습니다"라고 하세요.

전문 법률 조언:"""

    prompt = PromptTemplate(
        template=strict_prompt_template,
        input_variables=["context", "question"],
    )

    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=retriever,
        chain_type_kwargs={"prompt": prompt},
        return_source_documents=True,
        verbose=False,
    )

    return {
        "loader": loader,
        "splits": splits,
        "embeddings": embeddings,
        "vectorstore": vectorstore,
        "retriever": retriever,
        "llm": llm,
        "prompt": prompt,
        "qa_chain": qa_chain,
    }


INSUFFICIENT_MSG = "제시된 사례집에서는 확인할 수 없습니다"

def safe_answer(qa_chain, question: str, min_chars_in_context: int = 120):
    """
    Enforce the policy:
    1) Retrieve docs. If none or too short context -> return fixed fallback without calling LLM.
    2) Else call the RetrievalQA chain.
    3) Optionally post-check the output (conservative).
    """
    docs = qa_chain.retriever.get_relevant_documents(question)
    total_len = sum(len(getattr(d, "page_content", "")) for d in docs)

    if len(docs) == 0 or total_len < min_chars_in_context:
        return {"result": INSUFFICIENT_MSG, "source_documents": []}

    out = qa_chain.invoke({"query": question})

    text = (out.get("result") or "").strip()
    if not text:
        out["result"] = INSUFFICIENT_MSG

    return out

prompt_template_basic = """당신은 콘텐츠 분야 전문 법률 자문사입니다.

관련 분쟁사례: {context}
상담 내용: {question}

답변 가이드라인:
1. 사례를 근거로 답변하세요.
2. 관련 법령을 명시하세요.
3. 단계별 해결방안을 제시하세요.
4. 유사 사례를 참조하세요.
5. 없는 정보는 "제시된 사례집에서는 확인할 수 없습니다"라고 하세요.

전문 법률 조언:"""

prompt_basic = PromptTemplate(
    template=prompt_template_basic,
    input_variables=["context", "question"],
)


def run_demo_questions(qa_chain, questions: List[str]) -> None:
    """Run demo questions and print answers + simple source trace."""
    for i, q in enumerate(questions, 1):
        print("=" * 80)
        print(f"[Q{i}] {q}")
        result = safe_answer(qa_chain, q)
        print("\n[Answer]\n")
        print(result["result"].strip())

        print("\n[Top Sources]")
        srcs = result.get("source_documents", []) or []
        for j, d in enumerate(srcs, 1):
            meta = getattr(d, "metadata", {}) or {}
            source = meta.get("source", "")
            page = meta.get("page", None)
            if page is not None:
                print(f"  - ({j}) {source} | page {page}")
            else:
                print(f"  - ({j}) {source}")


if __name__ == "__main__":

    assert os.getenv("UPSTAGE_API_KEY"), "Please set UPSTAGE_API_KEY environment variable."

    components = build_rag_chain(
        pdf_path="./data/콘텐츠분쟁해결_사례.pdf", 
        use_mmr=False,   
        k=5,
        temperature=0.0,  
    )
    qa_chain = components["qa_chain"]

    test_questions = [
        "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
        "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
        "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
        "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
        "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?",
    ]

    run_demo_questions(qa_chain, test_questions)
# Out:
# ================================================================================
# [Q1] 온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?
# C:\Users\user\AppData\Local\Temp\ipykernel_19800\3929361239.py:153: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = qa_chain.retriever.get_relevant_documents(question)
# [Answer]
#
# ### 전문 법률 조언
#
# #### 1. **사례집 내 유사 사례 분석**
# 제시된 사례집에서 시스템 오류로 인한 아이템 복구 거부 사례와 관련된 다음과 같은 사례를 참조할 수 있습니다.
#
# - **2006_시스템 오류로 소멸된 아이템 복구 요구 (1-가-1)**
#   - **쟁점**: 시스템 오류로 인한 아이템 소멸 시 복구 의무 여부
#   - **결과**: 계정 명의자가 아닌 경우 복구 불가 (약관상 현금거래 및 계정 공유 금지 규정 적용).
#   - **시사점**: 계정 명의자 여부와 게임사의 약관이 복구 가능성에 결정적 영향을 미침.
#
# - **2009_시스템 오류로 인한 손실 아이템 복구 요구 (1-가-1)**
#   - **쟁점**: 시스템 오류 발생 여부 및 게임머니 소실 책임
#   - **결과**: 게임사는 시스템 오류 증거 불충분을 이유로 복구 거부.
#   - **시사점**: 게임사는 오류 발생 사실을 입증할 증거가 없는 경우 책임을 지지 않음.
#
# - **2006_프로그램 오류로 소멸된 아이템 복구 요구 (4-가-1)**
#   - **쟁점**: 프로그램 오류 인정 시 복구 의무
#   - **결과**: 게임사가 오류를 인정하고 아이템 복구.
#   - **시사점**: 게임사가 오류를 공식적으로 인정할 경우 복구 가능성 있음.
#
# #### 2. **관련 법령**
# - **민법 제250조(도품·유실물 반환청구권)**
#   - 게임 아이템이 "금전"에 해당하지 않는 경우, 유실물 반환 청구 가능.
#   - 단, 게임사가 아이템 소유권을 약관으로 보유한 경우 적용 제한적일 수 있음.
# - **전자상거래 등에서의 소비자보호에 관한 법률 제17조(결함 있는 재화에 대한 구제)**
#   - 시스템 오류가 "결함"으로 인정될 경우, 소비자는 수리·교환·환급 등을 요구할 수 있음.
#
# #### 3. **단계별 해결방안**
# **(1) 게임사와의 직접 협상**
# - **증거 수집**: 시스템 오류 발생 시점, 아이템 소멸 기록, 게임사와의 대화 내용(채팅·공지) 등을 스크린샷 또는 로그로 보존.
# - **공식 문의**: 게임사의 고객센터 또는 게시판을 통해 오류 인정 및 복구를 요청.
#   - *사례 4-가-1*에서 게임사가 오류를 인정한 경우 복구가 이루어진 사례 참조.
#
# **(2) 약관 및 책임 조항 확인**
# - 게임사의 이용약관에서 "시스템 오류 시 책임 범위"를 확인.
#   - *사례 1-가-1*에서 계정 명의자 여부와 약관 규정이 복구 거부의 근거가 됨.
#
# **(3) 한국소비자원 상담 또는 분쟁조정 신청**
# - **한국소비자원 조정전 상담**을 통해 게임사에 대한 압박 가능성 검토.
#   - *사례 1-가-1, 4-가-1*과 같이 소비자원의 중재로 게임사가 복구한 사례 존재.
# - **소비자분쟁조정위원회**에 조정 신청 (비용 무료).
#
# **(4) 소송 제기 (최후의 수단)**
# - 게임사가 고의·과실로 인한 손해를 입힌 경우, **민법 제750조(불법행위)**에 따라 손해배상 청구 가능.
#   - 단, 게임 아이템의 재산적 가치를 입증해야 하며, 약관으로 책임이 제한될 수 있음.
#
# #### 4. **주의사항**
# - **계정 명의자 여부**: 타인 명의 계정을 사용한 경우, 복구 요청이 거절될 수 있음 (*사례 1-가-1*).
# - **시스템 오류 입증**: 게임사가 오류를 인정하지 않으면 복구가 어려움 (*사례 2009_시스템 오류*).
# - **아이템 소유권**: 게임사가 아이템 소유권을 약관으로 보유한 경우, 법적 구제 범위가 제한될 수 있음.
#
# #### 5. **결론**
# - **즉시 실행 가능한 조치**: 게임사에 오류 증거를 제시하며 복구를 요청하고, 한국소비자원에 상담 신청.
# - **추가 조치**: 게임사가 응하지 않을 경우, 소비자분쟁조정위원회에 조정을 신청하거나 소송을 고려.
#
# > ※ 제시된 사례집에는 "시스템 오류로 인한 아이템 복구 거부" 시 **게임사가 오류를 인정하거나 소비자원의 중재가 있을 경우 복구 가능성**이 있음을 확인할 수 있습니다. 다만, 계정 명의자 여부나 오류 입증 여부에 따라 결과가 달라질 수 있습니다.
#
# > ※ "게임 아이템의 재산적 가치 평가 방법" 또는 "약관의 불공정 조항 판단 기준"과 같은 추가 정보는 **제시된 사례집에서는 확인할 수 없습니다**.
#
# [Top Sources]
#   - (1) ./data/콘텐츠분쟁해결_사례.pdf | page 8
#   - (2) ./data/콘텐츠분쟁해결_사례.pdf | page 28
#   - (3) ./data/콘텐츠분쟁해결_사례.pdf | page 2
#   - (4) ./data/콘텐츠분쟁해결_사례.pdf | page 9
#   - (5) ./data/콘텐츠분쟁해결_사례.pdf | page 10
# ================================================================================
# [Q2] 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?
#
# [Answer]
#
# ### 전문 법률 조언
#
# #### 1. **사례 근거 및 관련 법령**
# 제시된 사례집에 따르면, **온라인 교육 서비스 중도 해지 시 과도한 위약금 요구는 부당**할 수 있습니다.
# - **관련 법령**:
#   - **방문판매 등에 관한 법률 제29조(계약 해지)** 및 **제30조(위약금 등)**:
#     - 계속거래 계약 해지 시 소비자에게 "현저하게 초과하는 위약금"을 청구할 수 없음.
#     - 실제 공급된 서비스 대가를 초과하는 금액 반환을 거부할 수 없음.
#   - **소비자기본법에 따른 소비자분쟁해결기준(공정위고시, 인터넷콘텐츠업)**:
#     - 해지일까지의 이용일수 해당 금액 + 총 이용금액의 **10% 이내 위약금**만 공제 가능.
#     - 사은품 미사용 시 반환 의무 없음.
#
# #### 2. **단계별 해결방안**
# **(1) 계약서 확인**
# - 계약서에 명시된 **계약금액**, **중도해지 조건**, **위약금 비율**을 확인합니다.
#   - *사례 2008_온라인통신교육서비스 이용료 환급 요구2*: 실제 지불액과 계약서 금액이 다를 경우, **실제 지불액을 계약금액으로 인정**해야 함.
#
# **(2) 이용일수 및 위약금 산정**
# - **이용일수**: 서비스 개통일부터 해지일까지의 실제 이용 기간을 기준으로 계산.
#   - *사례 2010_인터넷 화상 강의 수강계약 해지*: 서비스 개통일을 이용 시작일로 인정.
# - **위약금**: 총 이용금액의 **10% 이내**만 공제 가능.
#   - *사례 2007_인터넷교육서비스 중도해지 요구*: 10% 초과 위약금은 부당.
#
# **(3) 부당 공제 항목 검토**
# - **가입비, 사은품 비용, 컨텐츠 비용** 등은 계약서에 명시되지 않았거나 실제 제공되지 않은 경우 공제 불가.
#   - *사례 2007_온라인통신교육서비스 대금 환급 요구2*: 학습컨텐츠 비용이 계약서에 명시되지 않아 공제 불가.
#
# **(4) 한국소비자원 또는 소비자분쟁조정위원회에 조정 신청**
# - 피청구인의 환급액이 소비자분쟁해결기준을 초과할 경우, **조정 신청**을 통해 환급액 재계산 가능.
#
# #### 3. **유사 사례 참조**
# - **2007_인터넷교육서비스 중도해지 요구**:
#   - 피청구인이 1,632,000원을 공제한 것은 부당하며, **이용일수 + 10% 위약금**만 공제해야 함.
# - **2010_화상불량으로 중도 해지한 인터넷강의 환급 요구**:
#   - 서비스 품질 문제로 인한 해지 시 위약금 면제 가능성 있음(사례집 미상세로 확인 불가).
#
# #### 4. **주의사항**
# - **구두 해지 통보**만으로는 효력이 불완전할 수 있으므로, **내용증명 우편**으로 해지 의사를 명확히 전달해야 합니다.
# - **사은품**을 사용한 경우, 해당 비용을 공제할 수 있으나 미사용 시 반환 의무 없음.
#
# ### 결론
# 과도한 위약금 요구는 **방문판매법 및 소비자분쟁해결기준 위반**일 수 있습니다. 계약서, 이용 내역, 공제 항목을 꼼꼼히 검토한 후, 부당하다고 판단될 경우 **한국소비자원(1372)**에 조정을 신청하시기 바랍니다.
#
# > ※ 단, **서비스 품질 문제로 인한 해지** 또는 **계약서에 별도 위약금 조항**이 있는 경우, 추가 검토가 필요할 수 있습니다. 제시된 사례집에서는 해당 사항에 대한 구체적 기준이 확인되지 않습니다.
#
# [Top Sources]
#   - (1) ./data/콘텐츠분쟁해결_사례.pdf | page 3
#   - (2) ./data/콘텐츠분쟁해결_사례.pdf | page 62
#   - (3) ./data/콘텐츠분쟁해결_사례.pdf | page 60
#   - (4) ./data/콘텐츠분쟁해결_사례.pdf | page 72
#   - (5) ./data/콘텐츠분쟁해결_사례.pdf | page 66
# ================================================================================
# [Q3] 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?
#
# [Answer]
#
# ### 전문 법률 조언
#
# #### 1. **사례 근거 및 관련 법령**
# - **사례 1 (2010_무료 이벤트 후 자동 소액 결제 요금 환급요구, 한국소비자원)**
#   - **쟁점**: 무료체험 기간 내 해지하지 않을 경우 자동 유료전환된다는 사실을 소비자가 인지하지 못한 경우, 사업자의 **중요내용 명시·고지의무 위반**이 성립하는지 여부.
#   - **결과**:
#     - 사업자가 이벤트 화면에 고지했으나, 활자 크기가 작아 확인이 어려웠고, 유료전환 시 추가 고지가 없었음 → **고지의무 위반**으로 부분적 책임 인정.
#     - 소비자도 이용약관에 동의하고 4개월간 이의 없이 결제한 점을 고려해 **피신청인(사업자)의 책임을 50%로 제한**.
#   - **관련 법령**:
#     - **약관의 규제에 대한 법률 제3조** (약관의 작성 및 설명의무)
#     - **소비자기본법** (소비자분쟁해결기준)
#
# - **사례 2 (2006_무료 광고 후 서비스 이용요금 청구, 전자거래분쟁조정위원회)**
#   - **쟁점**: 무료 광고로 유인한 후 자동가입 및 유료서비스 요금을 청구한 경우, 사업자의 **충분한 고지 의무 위반** 여부.
#   - **결과**:
#     - 무료 통화권 수령을 위해 휴대폰 결제가 필요하다는 표시가 불명확했음 → **사업자 책임 인정**.
#     - **환불 권고** 및 회원탈퇴 처리 결정.
#
# #### 2. **단계별 해결방안**
# 1. **고지 내용 확인**:
#    - 무료체험 가입 시 "자동 유료전환" 조건이 **명확히 표시**되었는지 확인 (예: 활자 크기, 반복 고지 여부).
#    - 이용약관에서 해당 내용을 **동의**했는지 확인.
#
# 2. **사업자 책임 판단**:
#    - 고지 내용이 불분명하거나 소비자가 인지하기 어려웠다면, **약관의 규제에 대한 법률 제3조 위반** 가능성 있음.
#    - 단, 소비자가 장기간(4개월 이상) 이의 없이 결제한 경우, **책임 분담** (예: 50%) 가능성 있음.
#
# 3. **환불 요청 절차**:
#    - **한국소비자원** 또는 **전자거래분쟁조정위원회**에 분쟁조정 신청.
#    - **소비자기본법**에 따른 환급 요구 (사업자 과실 비율에 따라 부분 환급 가능).
#
# 4. **법적 조치**:
#    - 사업자가 고지의무를 위반한 경우, **계약 취소** 또는 **손해배상 청구** 가능.
#    - 단, 소비자가 이용약관에 동의한 사실이 명확하면 **책임 제한**될 수 있음.
#
# #### 3. **유사 사례 참조**
# - **공정거래위원회 시정조치 (2009. 9. 27.)**:
#   - 무료체험 이벤트 참가 시 유료서비스 강제 가입 조항 및 중도해지 제한 조항을 **무효화**한 사례.
#   - 해당 조항이 소비자 보호 법규(약관규제법, 표시광고법)에 위반됨을 확인.
#
# #### 4. **주의사항**
# - **제시된 사례집에서는 확인할 수 없는 정보**:
#   - 자동 유료전환 시 **추가 고지 절차** (예: SMS 알림)의 구체적 기준.
#   - **환불 금액 산정 방법** (예: 미사용 기간 비율 계산).
#
# ### 결론
# - **환불 가능성**은 사업자의 **고지 충분성**과 소비자의 **이용 기간**에 따라 달라집니다.
# - 사례집에 따르면, 고지 미흡 시 **부분 환급(50%)**이 가능하며, 소비자분쟁조정기관을 통해 해결을 권장합니다.
#
# > ※ 참고: 실제 사안은 **계약 조건 및 증거 자료**에 따라 결과가 달라질 수 있으므로, 전문 법률 상담을 권장합니다.
#
# [Top Sources]
#   - (1) ./data/콘텐츠분쟁해결_사례.pdf | page 100
#   - (2) ./data/콘텐츠분쟁해결_사례.pdf | page 101
#   - (3) ./data/콘텐츠분쟁해결_사례.pdf | page 102
#   - (4) ./data/콘텐츠분쟁해결_사례.pdf | page 103
#   - (5) ./data/콘텐츠분쟁해결_사례.pdf | page 4
# ================================================================================
# [Q4] 미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?
#
# [Answer]
#
# ### 전문 법률 조언: 미성년자 부모 동의 없이 게임 아이템 구매 시 환불 가능성
#
# #### 1. **사례 근거 및 관련 법령**
# - **사례 1 (2008_부당결제대금 반환 청구)**:
#   - 미성년자가 타인 명의를 도용하여 게임 아이템을 구매한 경우, **민법 제5조(미성년자의 능력)** 및 **제741조(부당이득)**에 따라 계약 취소 가능성이 있으나, **불법행위(주민번호 도용)**로 인해 미성년자와 법정대리인(부모)이 책임을 분담할 수 있음.
#   - 조정 결과: **피신청인(게임사) 35%, 신청인(부모) 65%**의 손해 분담으로 부분 환불 결정.
#
# - **사례 2 (2006_미성년자 단독으로 한 결제 취소 청구)**:
#   - 미성년자가 성인 명의를 도용해 결제한 경우, **민법 제17조(무능력자의 사술)**에 따라 "사술 행위"로 간주되어 계약 취소가 제한될 수 있음.
#   - 단, **미성년자 본인 명의**로 결제한 금액에 한해 환불 권고.
#
# - **사례 3 (2008_미성년자의 신용카드 부정사용)**:
#   - 신용카드 4중 보안(카드번호, CVS, 비밀번호 등)을 우회한 결제는 "사술 행위"로 볼 여지가 있으나, **공정위 소비자분쟁해결기준**에 따라 **법정대리인 동의 없는 계약은 취소 가능**.
#   - 단, 게임사가 보안 절차를 이행한 경우 책임 감소 가능.
#
# #### 2. **단계별 해결방안**
# **(1) 계약 취소 요건 확인**
# - **미성년자 본인 명의**로 결제했는지, **성인 명의 도용** 여부를 확인합니다.
#   - *본인 명의*: **민법 제5조**에 따라 부모 동의 없이 체결한 계약은 취소 가능.
#   - *타인 명의 도용*: **불법행위**로 인해 환불 범위가 제한될 수 있음(사례 1 참조).
#
# **(2) 게임사의 보안 절차 검토**
# - 게임사가 **실명인증** 또는 **연령 확인 시스템**을 운영했는지 확인합니다.
#   - 시스템 미비 시: 게임사의 과실 인정 가능(사례 1에서 피신청인 35% 책임).
#   - 시스템 이행 시: 미성년자 사술 행위로 간주되어 환불 거부 가능(사례 2 참조).
#
# **(3) 환불 요청 및 조정 신청**
# - **전자거래분쟁조정위원회**에 조정을 신청해 **부분 환불**을 요구할 수 있습니다.
#   - 예시: 사례 1과 같이 **65% 부모 책임, 35% 게임사 책임**으로 분담 가능.
#
# **(4) 신용카드사 청구 취소**
# - 신용카드 결제 시 **"부정사용"**으로 신고해 **결제 취소**를 요청할 수 있습니다.
#   - 단, 게임사가 이미 아이템을 제공한 경우 **부분 환불**로 이어질 수 있음(사례 3 참조).
#
# #### 3. **유사 사례 참조**
# - **타인 명의 도용 + 장기 결제**: 부분 환불(사례 1).
# - **미성년자 본인 명의 + 게임사 시스템 미비**: 전액 취소 가능성 높음.
# - **성인 명의 도용 + 사술 행위**: 환불 거부 가능(사례 2).
#
# #### 4. **주의사항**
# - **증거 확보**: 결제 내역, 게임사와의 대화 기록, 자녀의 연령 증명 등을 보관하세요.
# - **게임사의 책임**: 실명인증 미이행 시 책임 비율 증가(사례 1).
#
# > ✅ **결론**: 환불 가능성은 **결제 방식(본인/타인 명의)**과 **게임사의 보안 절차**에 따라 달라집니다. 조정 신청을 통해 부분 환불을 요구할 수 있으며, 구체적인 사안은 **전자거래분쟁조정위원회**에 문의하시기 바랍니다.
#
# (※ 제시된 사례집 외 추가 정보는 "제시된 사례집에서는 확인할 수 없습니다"로 답변합니다.)
#
# [Top Sources]
#   - (1) ./data/콘텐츠분쟁해결_사례.pdf | page 50
#   - (2) ./data/콘텐츠분쟁해결_사례.pdf | page 43
#   - (3) ./data/콘텐츠분쟁해결_사례.pdf | page 51
#   - (4) ./data/콘텐츠분쟁해결_사례.pdf | page 52
#   - (5) ./data/콘텐츠분쟁해결_사례.pdf | page 53
# ================================================================================
# [Q5] 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?
#
# [Answer]
#
# ### 전문 법률 조언
#
# #### 1. **계약 해지 가능성**
# 제시된 사례집에 따르면, 온라인 교육 서비스 계약은 「방문판매 등에 관한 법률」 제29조에 따라 **계속적 거래**로 분류되며, 소비자는 **언제든지 계약을 해지할 권리**가 있습니다.
# - **유사 사례**:
#   - 2010_온라인교육 서비스 계약 해지 사례(69■)에서 신청인은 대학 합격으로 인해 1년 계약 중 1/12도 경과하지 않은 시점에서 해지할 수 있었습니다.
#   - 2007_인터넷교육서비스 중도해지 사례(57■)에서도 서비스 불만 사유로 중도 해지가 인정되었습니다.
#
# #### 2. **환급금 산정 기준**
# 계약 해지 시 환급금은 다음 법령에 따라 산정되어야 합니다:
# - **관련 법령**:
#   - 「방문판매 등에 관한 법률」 제30조: **과도한 위약금 청구 금지** (소비자의 손실을 현저히 초과하는 금액 불가).
#   - 「소비자기본법」 소비자분쟁해결기준(공정위고시, 인터넷콘텐츠업): **이용일수 공제 + 최대 10% 위약금** 적용.
# - **사례 적용**:
#   - 2008_온라인 통신교육서비스 사례(59■)에서 할인 전 금액이나 추가 비용(교재비, 가입비 등)을 공제하는 것은 부당하다고 판단되었습니다.
#   - 2007_온라인통신교육서비스 사례(55■)에서 계약서에 명시되지 않은 비용(학습컨텐츠 비용)을 공제한 것은 위법하다고 결정되었습니다.
#
# #### 3. **단계별 해결방안**
# 1. **계약 해지 통보**:
#    - 서면(이메일, 내용증명)으로 서비스 미제공 또는 광고와 다른 점을 명시하여 해지 의사를 전달합니다.
# 2. **환급금 요구**:
#    - **이용일수 공제**: 실제 이용한 기간에 해당하는 금액만 공제합니다.
#    - **위약금**: 총 이용요금의 **10% 이내**만 청구 가능합니다.
#    - **부당 공제 항목 제외**: 가입비, 사은품 비용 등 계약서에 명시되지 않은 항목은 환급금에서 제외할 수 없습니다.
# 3. **분쟁 발생 시**:
#    - 한국소비자원에 분쟁 조정을 신청하거나, 「방문판매 등에 관한 법률」 제45조(소비자 불리한 계약 금지)를 근거로 소송을 제기할 수 있습니다.
#
# #### 4. **주의사항**
# - **계약서 확인**: 환급금 산정 시 **계약서에 기재된 금액**을 기준으로 해야 합니다(2007_57■ 사례 참조).
# - **증거 확보**: 광고 내용과 실제 서비스 차이를 입증할 수 있는 자료(캡처, 이메일 등)를 보관합니다.
#
# #### 5. **확인 불가 사항**
# - "광고와 다르게 제공"된 구체적 사유(예: 강의 내용 부실, 기술 장애 등)에 대한 환급 기준은 제시된 사례집에서 **명시적으로 확인할 수 없습니다**. 다만, 서비스 미제공 또는 중대한 하자 시 전액 환급 가능성이 있습니다(2010_65■ 사례 참조).
#
# > ✅ **결론**: 계약 해지는 가능하며, 환급금은 이용일수 + 10% 위약금 범위 내에서 청구해야 합니다. 부당 공제 항목은 거부하고, 분쟁 시 소비자보호기관을 활용하세요.
#
# [Top Sources]
#   - (1) ./data/콘텐츠분쟁해결_사례.pdf | page 3
#   - (2) ./data/콘텐츠분쟁해결_사례.pdf | page 74
#   - (3) ./data/콘텐츠분쟁해결_사례.pdf | page 64
#   - (4) ./data/콘텐츠분쟁해결_사례.pdf | page 60
#   - (5) ./data/콘텐츠분쟁해결_사례.pdf | page 62
